# %%
#importing code for graphs & pandas for calculations
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
#importing csv file initially downloaded from Kaggle
auction = pd.read_csv('auction.csv')

# %%
#creating a dataframe using pandas dataframes and my auction file
auctiondf = pd.DataFrame(auction)

# %%
#view what i have in my dataset
auction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10681 entries, 0 to 10680
# Data columns (total 9 columns):
# auctionid       10681 non-null int64
# bid             10681 non-null float64
# bidtime         10681 non-null float64
# bidder          10665 non-null object
# bidderrate      10670 non-null float64
# openbid         10681 non-null float64
# price           10681 non-null float64
# item            10681 non-null object
# auction_type    10681 non-null object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 751.1+ KB

# %%
#view the top few rows
auctiondf.head()
# Out:
#     auctionid    bid   bidtime                     bidder  bidderrate  \
# 0  1638893549  175.0  2.230949               schadenfreud         0.0
# 1  1638893549  100.0  2.600116                      chuik         0.0
# 2  1638893549  120.0  2.600810                 kiwisstuff         2.0
# 3  1638893549  150.0  2.601076                 kiwisstuff         2.0
# 4  1638893549  177.5  2.909826  eli.flint@flightsafety.co         4.0
#
#    openbid  price                item   auction_type
# 0     99.0  177.5  Cartier wristwatch  3 day auction
# 1     99.0  177.5  Cartier wristwatch  3 day auction
# 2     99.0  177.5  Cartier wristwatch  3 day auction
# 3     99.0  177.5  Cartier wristwatch  3 day auction
# 4     99.0  177.5  Cartier wristwatch  3 day auction

# %%
auctiondf.tail()
# Out:
#         auctionid    bid   bidtime           bidder  bidderrate  openbid  \
# 10676  8214889177  61.00  6.359155           714ark        15.0     0.01
# 10677  8214889177  76.00  6.359294         rjdorman         1.0     0.01
# 10678  8214889177  90.00  6.428738       baylorjeep         3.0     0.01
# 10679  8214889177  88.00  6.760081  jasonjasonparis        18.0     0.01
# 10680  8214889177  90.01  6.988831          gpgtpse       268.0     0.01
#
#        price               item   auction_type
# 10676  90.01  Xbox game console  7 day auction
# 10677  90.01  Xbox game console  7 day auction
# 10678  90.01  Xbox game console  7 day auction
# 10679  90.01  Xbox game console  7 day auction
# 10680  90.01  Xbox game console  7 day auction

# %%
#
auctiondf.describe(include = "all")
# Out:
#            auctionid           bid       bidtime        bidder    bidderrate  \
# count   1.068100e+04  10681.000000  10681.000000         10665  10670.000000
# unique           NaN           NaN           NaN          3387           NaN
# top              NaN           NaN           NaN  warrencheryl           NaN
# freq             NaN           NaN           NaN            45           NaN
# mean    4.136148e+09    207.586109      3.979628           NaN     31.936739
# std     2.489918e+09    323.037396      2.353386           NaN    120.594074
# min     1.638844e+09      0.010000      0.000567           NaN     -4.000000
# 25%     3.015329e+09     72.000000      1.949931           NaN      1.000000
# 50%     3.020526e+09    140.000000      4.140833           NaN      5.000000
# 75%     8.212136e+09    210.000000      6.448060           NaN     21.000000
# max     8.215611e+09   5400.000000      6.999990           NaN   3140.000000
#
# ...

# %%
#i want to create a new df where i only include values for the cartier
#instead of droping values, i am making a new df without values i dont want
auctiondf2 = auctiondf[auctiondf.item == "Cartier wristwatch"]

# %%
#checking to see if it worked!
auctiondf2.tail()
# Out:
#        auctionid     bid   bidtime      bidder  bidderrate  openbid  price  \
# 1948  1650986455  150.00  0.693542      jmsolo       138.0     9.99  405.0
# 1949  1650986455  278.75  0.755926       fveta        36.0     9.99  405.0
# 1950  1650986455  405.00  0.889213     gram999        12.0     9.99  405.0
# 1951  1650986455  400.00  1.693403  sandseller         6.0     9.99  405.0
# 1952  1650986455  405.00  2.916481     gram999        12.0     9.99  405.0
#
#                     item   auction_type
# 1948  Cartier wristwatch  7 day auction
# 1949  Cartier wristwatch  7 day auction
# 1950  Cartier wristwatch  7 day auction
# 1951  Cartier wristwatch  7 day auction
# 1952  Cartier wristwatch  7 day auction

# %%
#checking out new data
auctiondf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1953 entries, 0 to 1952
# Data columns (total 9 columns):
# auctionid       1953 non-null int64
# bid             1953 non-null float64
# bidtime         1953 non-null float64
# bidder          1953 non-null object
# bidderrate      1953 non-null float64
# openbid         1953 non-null float64
# price           1953 non-null float64
# item            1953 non-null object
# auction_type    1953 non-null object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 152.6+ KB

# %%
#now that i have the data i want, i am renaming for ease
df = auctiondf2

# %%
df.describe()
# Out:
#           auctionid          bid      bidtime   bidderrate      openbid  \
# count  1.953000e+03  1953.000000  1953.000000  1953.000000  1953.000000
# mean   1.644534e+09   569.876124     3.527637    31.532002   153.437184
# std    3.586360e+06   621.013303     2.356856    96.175264   360.694417
# min    1.638844e+09     1.000000     0.007535    -4.000000     0.010000
# 25%    1.641587e+09   150.000000     1.252407     1.000000     1.000000
# 50%    1.644139e+09   335.000000     3.023947     5.000000     9.990000
# 75%    1.647847e+09   800.000000     5.861042    27.000000   150.000000
# max    1.650986e+09  5400.000000     6.999965  1838.000000  5000.000000
#
#              price
# count  1953.000000
# mean    925.047906
# std     765.400140
# min      26.000000
# 25%     355.000000
# 50%     620.000000
# 75%    1524.990000
# max    5400.000000

# %%
df.describe(include = "all")
# Out:
#            auctionid          bid      bidtime    bidder   bidderrate  \
# count   1.953000e+03  1953.000000  1953.000000      1953  1953.000000
# unique           NaN          NaN          NaN       678          NaN
# top              NaN          NaN          NaN  lass1004          NaN
# freq             NaN          NaN          NaN        29          NaN
# mean    1.644534e+09   569.876124     3.527637       NaN    31.532002
# std     3.586360e+06   621.013303     2.356856       NaN    96.175264
# min     1.638844e+09     1.000000     0.007535       NaN    -4.000000
# 25%     1.641587e+09   150.000000     1.252407       NaN     1.000000
# 50%     1.644139e+09   335.000000     3.023947       NaN     5.000000
# 75%     1.647847e+09   800.000000     5.861042       NaN    27.000000
# max     1.650986e+09  5400.000000     6.999965       NaN  1838.000000
#
#             openbid        price                item   auction_type
# ...

# %%
df.groupby('auction_type').mean()
# Out:
#                   auctionid         bid   bidtime  bidderrate     openbid  \
# auction_type
# 3 day auction  1.644726e+09  422.631320  1.968105   20.664000  165.721440
# 5 day auction  1.644473e+09  564.617408  2.811271   30.338028  162.837662
# 7 day auction  1.644515e+09  598.569036  4.005524   33.862018  148.683301
#
#                     price
# auction_type
# 3 day auction  678.779800
# 5 day auction  960.790620
# 7 day auction  961.307819

# %%
#most variance of open bids in 7 day auctions
df.groupby(['auction_type', 'openbid']).mean()
# Out:
#                           auctionid          bid   bidtime  bidderrate  \
# auction_type  openbid
# 3 day auction 1.00     1.639454e+09   149.371212  1.686570    2.666667
#               9.99     1.643903e+09    24.127647  2.482363   36.058824
#               99.00    1.644910e+09   201.686429  2.251308    8.767857
#               99.99    1.646102e+09   528.650857  1.580307   20.285714
#               100.00   1.645121e+09   336.491892  2.605245   10.513514
#               149.99   1.645883e+09   334.958333  1.111733  165.333333
#               150.00   1.648233e+09   169.875000  1.766774   10.000000
#               199.00   1.646631e+09   340.811875  1.866936    0.312500
#               200.00   1.643076e+09   759.062500  1.271674    6.312500
#               500.00   1.649727e+09  1492.230769  1.637226   56.538462
#               1200.00  1.646354e+09  1488.636364  2.225615    0.909091
# 5 day auction 1.00     1.645317e+09   522.428954  2.369635   40.039216
# ...

# %%
#histograms to start seeing distributions of data
plt.hist(df.auction_type)
# Out:
# (array([ 250.,    0.,    0.,    0.,    0.,  355.,    0.,    0.,    0.,
#         1348.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df.price)
# Out:
# (array([935., 403., 245., 246.,  75.,  34.,   0.,  11.,   0.,   4.]),
#  array([  26. ,  563.4, 1100.8, 1638.2, 2175.6, 2713. , 3250.4, 3787.8,
#         4325.2, 4862.6, 5400. ]),
#  <a list of 10 Patch objects>)

# %%
sns.stripplot('auction_type', 'price', data = df, jitter = True)

# %%
df7 = df[df.auction_type == '7 day auction']
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1348 entries, 605 to 1952
# Data columns (total 9 columns):
# auctionid       1348 non-null int64
# bid             1348 non-null float64
# bidtime         1348 non-null float64
# bidder          1348 non-null object
# bidderrate      1348 non-null float64
# openbid         1348 non-null float64
# price           1348 non-null float64
# item            1348 non-null object
# auction_type    1348 non-null object
# dtypes: float64(5), int64(1), object(3)
# memory usage: 105.3+ KB

# %%
df7.describe(include = "all")
# Out:
#            auctionid          bid      bidtime    bidder   bidderrate  \
# count   1.348000e+03  1348.000000  1348.000000      1348  1348.000000
# unique           NaN          NaN          NaN       509          NaN
# top              NaN          NaN          NaN  lass1004          NaN
# freq             NaN          NaN          NaN        22          NaN
# mean    1.644515e+09   598.569036     4.005524       NaN    33.862018
# std     3.597128e+06   659.814384     2.497989       NaN    87.511146
# min     1.638844e+09     1.000000     0.007535       NaN    -4.000000
# 25%     1.641699e+09   151.660000     1.505715       NaN     1.000000
# 50%     1.644198e+09   353.000000     4.170885       NaN     6.000000
# 75%     1.647847e+09   821.500000     6.725284       NaN    31.000000
# max     1.650986e+09  5400.000000     6.999965       NaN  1303.000000
#
#             openbid        price                item   auction_type
# ...

# %%
df7.head()
# Out:
#       auctionid     bid   bidtime       bidder  bidderrate  openbid   price  \
# 605  1638843936   500.0  0.478368    kona-java       181.0    500.0  1625.0
# 606  1638843936   800.0  0.826389       doc213        60.0    500.0  1625.0
# 607  1638843936   600.0  3.761123         zmxu         7.0    500.0  1625.0
# 608  1638843936  1500.0  5.226377  carloss8055         5.0    500.0  1625.0
# 609  1638843936  1600.0  6.570625      jdrinaz         6.0    500.0  1625.0
#
#                    item   auction_type
# 605  Cartier wristwatch  7 day auction
# 606  Cartier wristwatch  7 day auction
# 607  Cartier wristwatch  7 day auction
# 608  Cartier wristwatch  7 day auction
# 609  Cartier wristwatch  7 day auction

# %%
df7.tail()
# Out:
#        auctionid     bid   bidtime      bidder  bidderrate  openbid  price  \
# 1948  1650986455  150.00  0.693542      jmsolo       138.0     9.99  405.0
# 1949  1650986455  278.75  0.755926       fveta        36.0     9.99  405.0
# 1950  1650986455  405.00  0.889213     gram999        12.0     9.99  405.0
# 1951  1650986455  400.00  1.693403  sandseller         6.0     9.99  405.0
# 1952  1650986455  405.00  2.916481     gram999        12.0     9.99  405.0
#
#                     item   auction_type
# 1948  Cartier wristwatch  7 day auction
# 1949  Cartier wristwatch  7 day auction
# 1950  Cartier wristwatch  7 day auction
# 1951  Cartier wristwatch  7 day auction
# 1952  Cartier wristwatch  7 day auction

# %%
plt.hist(df7.price)
#very skewed right
# Out:
# (array([675., 276., 141., 149.,  58.,  34.,  11.,   0.,   0.,   4.]),
#  array([ 103.5 ,  633.15, 1162.8 , 1692.45, 2222.1 , 2751.75, 3281.4 ,
#         3811.05, 4340.7 , 4870.35, 5400.  ]),
#  <a list of 10 Patch objects>)

# %%
df7.price.skew()
# Out:
# 1.5317158072503658

# %%
plt.hist(df7.auctionid)
# Out:
# (array([189., 104., 122., 145., 323.,  25.,  55., 131., 114., 140.]),
#  array([1.63884394e+09, 1.64005819e+09, 1.64127244e+09, 1.64248669e+09,
#         1.64370094e+09, 1.64491520e+09, 1.64612945e+09, 1.64734370e+09,
#         1.64855795e+09, 1.64977220e+09, 1.65098646e+09]),
#  <a list of 10 Patch objects>)

# %%
sns.barplot('auctionid', 'price', data = df7)

# %%
plt.scatter(df7.bid, df7.price)
#as expected, the opening bid price increases so does the price of the lot

# %%
plt.scatter(df7.bidderrate, df7.price)
plt.ylabel('price')

#weird that as price increases the rating goes down
# Out:
# Text(0,0.5,'price')

# %%
#would be cool to see...
#estimates: range between estimate and price
#details on the client - understanding what the bidderrating means exactly
#opening bid set by the seller v price
#seeing who the winner was and bidderrating
#the above - more detail may be needed for only looking at df7

# %%
plt.hist(df7.bidtime)
# Out:
# (array([160., 163., 124.,  84.,  71.,  76.,  68.,  68., 112., 422.]),
#  array([0.00753472, 0.70677778, 1.40602083, 2.10526389, 2.80450694,
#         3.50375   , 4.20299306, 4.90223611, 5.60147917, 6.30072222,
#         6.99996528]),
#  <a list of 10 Patch objects>)

# %%
sns.barplot('bidtime', 'price', data = df7)
